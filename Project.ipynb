# %% [markdown]
# # Project

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG (1).csv" , encoding="latin-1")

# %%
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.head(20)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
Item=data.groupby("Item").sum()

# %%
Item
# Out:
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# Vegetal Products         18060     391905         90990  107145.19  107064.17
# Wheat and products       87073    1639683       2654934  232670.13  234710.51
# Wine                     66206    1319535       1818328    4497.36    4251.81
# Yams                     50798     970905       1525745  200396.96  203151.78
#
# ...

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
grouped=data.groupby("Element")

# %%
print(grouped["Y2018"].agg([np.size, np.max, np.mean, np.min]))
# Out:
#                                         size       amax          mean    amin
# Element
# Domestic supply quantity                5295  117038.00    411.185712  -184.0
# Export Quantity                         4403   34641.00     49.806583     0.0
# Fat supply quantity (g/capita/day)      5023      94.94      2.057086     0.0
# Feed                                    1319   31567.00    190.603820     0.0
# Food                                    4941   54077.00    265.385972     0.0
# Food supply (kcal/capita/day)           5014    3450.00     91.620246     0.0
# Food supply quantity (kg/capita/yr)     4905     443.56     10.058817     0.0
# Import Quantity                         5139   18036.00     58.240059     0.0
# Losses                                  2009   10355.00     81.624502     0.0
# Other uses (non-food)                   1732   17221.00     55.166749     0.0
# Processing                              2010   22609.00    153.983525     0.0
# ...

# %%
maximum=group["Y2014"].agg(np.max)

# %%
maximum
# Out:
# 1996716.35

# %%
area=data.groupby("Area")

# %%
print(area["Y2018"].agg([np.size, np.max, np.mean, np.min]))
# Out:
#                              size       amax         mean    amin
# Area
# Algeria                      1313   42228.00   263.274253   -90.0
# Angola                       1424   30810.00   168.486160  -240.0
# Benin                        1285   11485.00    99.808866  -256.0
# Botswana                     1378    2342.00    16.994181   -35.0
# Burkina Faso                 1409   19751.00    82.280204   -77.0
# Cabo Verde                   1260    2541.00    12.267282   -16.0
# Cameroon                     1460   25216.00   162.725510  -175.0
# Central African Republic     1344    4666.00    23.013433    -4.0
# Chad                         1343   15478.00    55.388690   -10.0
# Comoros                        45      16.65     1.329778     0.0
# Congo                        1413    5244.00    30.505105   -17.0
# Côte d'Ivoire                1467   25069.00   156.026117  -151.0
# Djibouti                     1095    2694.00    22.806692   -10.0
# ...
